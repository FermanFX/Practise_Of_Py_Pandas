# %%
import pandas as pd

# %%
df = pd.read_csv("calisanlar.csv")

# %%
df
# Out:
#   calisanlar  maaslar
# 0        Ali     5000
# 1       Veli     6000
# 2       Ayse     7000

# %%
student = [
    {"calisanlar": "mehemmedeli", "maaslar": "7000"},
    {"calisanlar": "mehemmed", "maaslar": "8000"}
]

# %%
df = pd.DataFrame(student)

# %%
df
# Out:
#     calisanlar maaslar
# 0  mehemmedeli    7000
# 1     mehemmed    8000

# %%
mellimler ={
    "calisanlar": ["aygul","gunay"],
    "Surname": ["khanli", "Bayramli"]
}

# %%
df = pd.DataFrame(mellimler)

# %%
df
# Out:
#   calisanlar   Surname
# 0      aygul    khanli
# 1      gunay  Bayramli

# %%
df['suname']
# Out:
# -------------------------------------------------------------
# KeyError                    Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df[surname]
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df[surname]
#
# NameError: name 'surname' is not defined

# %%
df['Surname']
# Out:
# 0      khanli
# 1    Bayramli
# Name: Surname, dtype: str

# %%
type(df['Surname'])
# Out:
# pandas.Series

# %%
df.surname
# Out:
# -------------------------------------------------------------
# AttributeError              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.surname
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'surname'

# %%
df.Surname
# Out:
# 0      khanli
# 1    Bayramli
# Name: Surname, dtype: str

# %%
df[
    ['calisanlar', 'Surname']
]
# Out:
#   calisanlar   Surname
# 0      aygul    khanli
# 1      gunay  Bayramli

# %%
df.columns
# Out:
# Index(['calisanlar', 'Surname'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.iloc[1]
# Out:
# calisanlar       gunay
# Surname       Bayramli
# Name: 1, dtype: str

# %%
df.index= df.index +5

# %%
df.iloc[1]
# Out:
# calisanlar       gunay
# Surname       Bayramli
# Name: 6, dtype: str

# %%
df.loc[1]
# Out:
# -------------------------------------------------------------
# ValueError                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                    Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.loc[1]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# ...

# %%
df.loc[5]
# Out:
# calisanlar     aygul
# Surname       khanli
# Name: 5, dtype: str

# %%
df.shape
# Out:
# (2, 2)
